# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %%
venus = pd.read_csv('../data/venus.csv')
earth = pd.read_csv('../data/earth.csv')
mars = pd.read_csv('../data/mars.csv')
jupiter = pd.read_csv('../data/jupiter.csv')
saturn = pd.read_csv('../data/saturn.csv')
titan = pd.read_csv('../data/titan.csv')
uranus = pd.read_csv('../data/uranus.csv')
neptune = pd.read_csv('../data/neptune.csv')

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(venus['Density_kgm3'], venus['Height_km'], color='xkcd:orange', linestyle='dashed', linewidth=2.0, label="Venus")
plt.plot(earth['rho'], earth['H']/1e3, color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Earth")
plt.plot(mars['Density_kgm3'], mars['Height_km'], color='xkcd:red', linestyle='dashdot', linewidth=2.0, label="Mars")

plt.xlabel("Density, kg/m3",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.xscale('log')
plt.yticks(fontsize=14)
plt.xticks(np.logspace(-9, 2, 12), fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/venus-earth-mars-density.png', dpi= 300, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(venus['Pressure_Pa']/1e5, venus['Height_km'], color='xkcd:orange', linestyle='dashed', linewidth=2.0, label="Venus")
plt.plot(earth['P']/1e5, earth['H']/1e3, color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Earth")
plt.plot(mars['Pressure_Pa']/1e5, mars['Height_km'], color='xkcd:red', linestyle='dashdot', linewidth=2.0, label="Mars")

plt.xlabel("Pressure, bar",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.xscale('log')
plt.yticks(fontsize=14)
plt.xticks(np.logspace(-9, 2, 12), fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/venus-earth-mars-pressure.png', dpi= 300, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(venus['Temperature_K'], venus['Height_km'], color='xkcd:orange', linestyle='dashed', linewidth=2.0, label="Venus")
plt.plot(earth['T(K)'], earth['H']/1e3, color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Earth")
plt.plot(mars['Temperature_K'], mars['Height_km'], color='xkcd:red', linestyle='dashdot', linewidth=2.0, label="Mars")

plt.xlabel("Temperature, K",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/venus-earth-mars-temperature.png', dpi= 300, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(jupiter['Density_kgm3'], jupiter['Height_km'], color='xkcd:brown', linestyle='dashed', linewidth=2.0, label="Jupiter")
plt.plot(saturn['rho'], saturn['Height'], color='xkcd:orange', linestyle='solid', linewidth=2.0, label="Saturn")
plt.plot(titan['Density_kgm3'], titan['Height_km'], color='xkcd:dark yellow', linestyle='dashdot', linewidth=2.0, label="Titan")
plt.plot(uranus['Density_kgm3'], uranus['Height_km'], color='xkcd:aquamarine', linestyle='solid', linewidth=2.0, label="Uranus")
plt.plot(neptune['Density_kgm3'], neptune['Height_km'], color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Neptune")

plt.xlabel("Density, kg/m3",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.xscale('log')
plt.yticks(fontsize=14)
plt.xticks(np.logspace(-10, 2, 13), fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/outer-planets-density.png', dpi= 300, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(jupiter['Pressure_Pa']/1e5, jupiter['Height_km'], color='xkcd:brown', linestyle='dashed', linewidth=2.0, label="Jupiter")
plt.plot(saturn['P']/1e5, saturn['Height'], color='xkcd:orange', linestyle='solid', linewidth=2.0, label="Saturn")
plt.plot(titan['Pressure_Pa']/1e5, titan['Height_km'], color='xkcd:dark yellow', linestyle='dashdot', linewidth=2.0, label="Titan")
plt.plot(uranus['Pressure_Pa']/1e5, uranus['Height_km'], color='xkcd:aquamarine', linestyle='solid', linewidth=2.0, label="Uranus")
plt.plot(neptune['Pressure_Pa']/1e5, neptune['Height_km'], color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Neptune")

plt.xlabel("Pressure, bar",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.xscale('log')
plt.yticks(fontsize=14)
plt.xticks(np.logspace(-10, 2, 13), fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/outer-planets-pressure.png', dpi= 300, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(jupiter['Temperature_K'], jupiter['Height_km'], color='xkcd:brown', linestyle='dashed', linewidth=2.0, label="Jupiter")
plt.plot(saturn['T(K)'], saturn['Height'], color='xkcd:orange', linestyle='solid', linewidth=2.0, label="Saturn")
plt.plot(titan['Temperature_K'], titan['Height_km'], color='xkcd:dark yellow', linestyle='dashdot', linewidth=2.0, label="Titan")
plt.plot(uranus['Temperature_K'], uranus['Height_km'], color='xkcd:aquamarine', linestyle='solid', linewidth=2.0, label="Uranus")
plt.plot(neptune['Temperature_K'], neptune['Height_km'], color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Neptune")

plt.xlabel("Temperature, K",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.legend(loc='lower right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/outer-planets-temperature.png', dpi= 300, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches([10.25, 4.25])

plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(earth['T(K)'], earth['H']/1e3, color='xkcd:blue', linestyle='solid', linewidth=2.0, label="Earth")
plt.plot(titan['Temperature_K'], titan['Height_km'], color='xkcd:dark yellow', linestyle='solid', linewidth=2.0, label="Titan")


plt.xlabel("Temperature, K",fontsize=14)
plt.ylabel("Altitude, km",fontsize=14)
plt.yscale('log')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.logspace(0, 3, 4), fontsize=14)
plt.grid('on',linestyle='-', linewidth=0.2)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=2, length=4)
ax.yaxis.set_tick_params(width=2, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')
ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.xlim([40, 300])
plt.legend(loc='upper right', fontsize=14, framealpha=0.8)

plt.savefig('../plots/earth-titan-temperature.png', dpi= 300, bbox_inches='tight')

plt.show()

# %%
CO2 = [venus['CO2mass_pct'][0], 0, mars['CO2mass_pct'][0], 0, 0, 0, 0, 0][::-1]
N2 = [venus['N2mass_pct'][0], 75.5 , mars['N2mass_pct'][0], 0, 0, titan['N2mass_pct'][0], 0, 0][::-1]
Ar = [0, 1.23 , mars['Armass_pct'][0], 0, 0, titan['Armass_pct'][0] , 0, 0][::-1]
CO = [venus['COmass_pct'][0], 0, mars['COmass_pct'][0], 0, 0, 0, 0, 0][::-1]
O2 = [0, 23.1, 0, 0, 0, 0, 0, 0][::-1]
H2 = [0, 0, 0, 90, 90, 0, uranus['H2mass_pct'][86], neptune['H2mass_pct'][101]][::-1]
He = [0, 0, 0, 10, 10, 0, uranus['Hemass_pct'][86], neptune['Hemass_pct'][101]][::-1]
CH4 = [0, 0, 0, 0, 0, titan['CH4mass_pct'][0], uranus['CH4mass_pct'][86], neptune['CH4mass_pct'][101]][::-1]

index = ['Venus', 'Earth', 'Mars', 'Jupiter',  'Saturn', 'Titan', 'Uranus', 'Neptune'][::-1]
comp_df = pd.DataFrame({'CO2': CO2, 'N2': N2, 'Ar': Ar, 'CO': CO, 'O2': O2, 'H2': H2, 'He': He, 'CH4': CH4}, index=index)

# %%
comp_df
# Out:
#            CO2     N2    Ar    CO    O2     H2     He    CH4
# Neptune   0.00   0.00  0.00  0.00   0.0  61.70  28.66   9.64
# Uranus    0.00   0.00  0.00  0.00   0.0  65.58  24.02  10.40
# Titan     0.00  95.32  3.15  0.00   0.0   0.00   0.00   1.53
# Saturn    0.00   0.00  0.00  0.00   0.0  90.00  10.00   0.00
# Jupiter   0.00   0.00  0.00  0.00   0.0  90.00  10.00   0.00
# Mars     96.11   2.00  1.71  0.07   0.0   0.00   0.00   0.00
# Earth     0.00  75.50  1.23  0.00  23.1   0.00   0.00   0.00
# Venus    97.74   2.26  0.00  0.00   0.0   0.00   0.00   0.00

# %%
comp_df.plot.barh(stacked=True, figsize=(10, 5), color=plt.cm.Paired(np.arange(len(comp_df))))

plt.xlabel("Mass percent",fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)

ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.xaxis.set_tick_params(width=1, length=4)
ax.yaxis.set_tick_params(width=1, length=4)
ax.xaxis.set_tick_params(width=1, length=4, which='minor')
ax.yaxis.set_tick_params(width=1, length=4, which='minor')

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.5)
plt.xlim([0, 101])

plt.legend(fontsize=14, framealpha=0.8, bbox_to_anchor=(1.0, 1.0))

plt.savefig('../plots/composition.png', dpi= 300, bbox_inches='tight')
plt.show()
