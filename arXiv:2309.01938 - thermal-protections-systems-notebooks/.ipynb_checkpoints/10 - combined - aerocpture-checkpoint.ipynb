# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a planet objecta
planet1=Planet("VENUS")
planet1.h_skip = 150000.0
planet1.h_trap = 20E3
planet1.loadAtmosphereModel('../atmdata/venus-gram-avg.dat', 0 , 1 ,2, 3)

planet2=Planet("EARTH")
planet2.h_skip = 120000.0
planet2.loadAtmosphereModel('../atmdata/earth-gram-avg.dat', 0 , 1 ,2, 3)

planet3 = Planet('MARS')
planet3.loadAtmosphereModel('../atmdata/mars-gram-avg.dat', 0 , 1 ,2, 3)
planet3.h_skip = 120.0E3
planet3.h_trap = 0E3

planet4=Planet("JUPITER")
planet4.h_skip = 1000E3
planet4.h_trap =  0.0E3
planet4.loadAtmosphereModel('../atmdata/jupiter-galileo-asi.dat', 0 , 1 , 2, 3, heightInKmFlag=True)

planet5=Planet("SATURN")
planet5.h_skip = 1000E3
planet5.h_trap =  0.0E3
planet5.loadAtmosphereModel('../atmdata/saturn-nominal.dat', 0 , 1 , 2, 3, heightInKmFlag=True)

planet6 = Planet('TITAN')
planet6.loadAtmosphereModel('../atmdata/titan-gram-avg.dat', 0 , 1 ,2, 3)
planet6.h_skip = 1000.0E3

planet7=Planet("URANUS")
planet7.h_skip = 1000e3
planet7.loadAtmosphereModel('../atmdata/uranus-gram-avg.dat', 0 , 1 ,2, 3, heightInKmFlag=True)
planet7.h_low = 120e3
planet7.h_trap= 0e3

planet8=Planet("NEPTUNE")
planet8.h_skip = 1000e3
planet8.loadAtmosphereModel('../atmdata/neptune-gram-avg.dat', 0 , 7 ,6, 5 , heightInKmFlag=True)
planet8.h_low = 120e3
planet8.h_trap= 0e3

# %%
# Set up a vehicle for drag modulation aerocapture and propagate the aerocapture trajectory
vehicle1=Vehicle('SmallSat1', 37, 20, 0.0, 1.767, 0.0, 0.35, planet1)
vehicle1.setInitialState(150.0,-6.22,23.16,10.8191,89.9982,-5.00,0.0,0.0)
vehicle1.setSolverParams(1E-6)
vehicle1.setDragModulationVehicleParams(20, 7.5)

# Set planet.h_low to 10 km, if vehicle dips below this level
# trajctory is terminated.
planet1.h_low=10.0E3

# Set target orbit = 2000 km x 2000 km, tolerance = 20 km
# target apo intentionally set to slightly higher value to account for bias in guidance
vehicle1.setTargetOrbitParams(200.0, 2000.0, 20.0)

# Set entry phase parameters
# v_switch_kms = 2.0, lowAlt_km = 20.0,
# numPoints_lowAlt = 101, hdot_threshold = -200.0 m/s.
# These are somewhat arbitary based on experience.
vehicle1.setDragEntryPhaseParams(2.0, 20.0, 101, -200.0)

# Set beta_1 and beta_ratio
vehicle1.setDragModulationVehicleParams(20, 7.5)

# Set vehicle initial state
vehicle1.setInitialState(150.0,-6.22,23.16,10.8191,89.9982,-5.20,0.0,0.0)
# Propogate a single vehicle trajectory
vehicle1.propogateGuidedEntryD2(1.0,1.0,0.1,2400.0)

# %%
# Set up a vehicle for drag modulation aerocapture and propagate the aerocapture trajectory
vehicle4=Vehicle('SmallSat1', 37, 20, 0.0, 1.767, 0.0, 0.35, planet2)
vehicle4.setInitialState(120.0,-6.22,23.16,10.8191,89.9982,-5.00,0.0,0.0)
vehicle4.setSolverParams(1E-6)
vehicle4.setDragModulationVehicleParams(20, 7.5)

# Set planet.h_low to 10 km, if vehicle dips below this level
# trajctory is terminated.
planet2.h_low=10.0E3

# Set target orbit = 2000 km x 2000 km, tolerance = 20 km
# target apo intentionally set to slightly higher value to account for bias in guidance
vehicle4.setTargetOrbitParams(200.0, 2000.0, 20.0)

# Set entry phase parameters
# v_switch_kms = 2.0, lowAlt_km = 20.0,
# numPoints_lowAlt = 101, hdot_threshold = -200.0 m/s.
# These are somewhat arbitary based on experience.
vehicle4.setDragEntryPhaseParams(2.0, 20.0, 101, -200.0)

# Set beta_1 and beta_ratio
vehicle4.setDragModulationVehicleParams(20, 7.5)

# Set vehicle initial state
vehicle4.setInitialState(120.0,-6.22,23.16,10.8191,89.9982,-4.40,0.0,0.0)
# Propogate a single vehicle trajectory
vehicle4.propogateGuidedEntryD2(1.0,1.0,0.1,2400.0)

# %%
# Set up a vehicle object
vehicle7=Vehicle('MarsSmallSat1', 37, 20, 0.0, 1.767, 0.0, 0.35, planet3)
vehicle7.setInitialState(120.0,88.15,-0.65,5.3581,8.5458,-5.00,0.0,0.0)
vehicle7.setSolverParams(1E-6)
vehicle7.setDragModulationVehicleParams(20, 7.5)

planet3.h_low = 10e3
# Set target orbit = 2000 km x 2000 km, tolerance = 20 km
# target apo intentionally set to slightly higher value to account for bias in guidance
vehicle7.setTargetOrbitParams(200.0, 2500.0, 20.0)

# Set entry phase parameters
# v_switch_kms = 2.0, lowAlt_km = 20.0,
# numPoints_lowAlt = 101, hdot_threshold = -200.0 m/s.
# These are somewhat arbitary based on experience.
vehicle7.setDragEntryPhaseParams(2.0, 20.0, 101, -200.0)

# Set beta_1 and beta_ratio
vehicle7.setDragModulationVehicleParams(20, 7.5)

# Set vehicle initial state
vehicle7.setInitialState(120.0,88.15,-0.65,5.3581,8.5458,-9.2,0.0,0.0)
# Propogate a single vehicle trajectory
vehicle7.propogateGuidedEntryD2(0.5,1.0,0.1,2400.0)

# %%
vehicle13=Vehicle('TitanOrbiter', 5700, 30, 0.0, 113.0, 0.0, 1.00, planet6)
vehicle13.setInitialState(1000, -23.67, 14.89, 7.3384, 90.1226, -5.00, 0.0,0.0)
vehicle13.setSolverParams(1E-5)
vehicle13.setDragModulationVehicleParams(30, 4.14)

# Set planet.h_low to 10 km, if vehicle dips below this level
# trajctory is terminated.
planet6.h_low=50.0E3

# Set target orbit = 2000 km x 2000 km, tolerance = 20 km
# target apo intentionally set to slightly higher value to account for bias in guidance
vehicle13.setTargetOrbitParams(1700, 1700, 20.0)

# Set entry phase parameters
# v_switch_kms = 2.0, lowAlt_km = 20.0,
# numPoints_lowAlt = 101, hdot_threshold = -200.0 m/s.
# These are somewhat arbitary based on experience.
vehicle13.setDragEntryPhaseParams(2.0, 50.0, 101, -200.0)

# Set beta_1 and beta_ratio
vehicle13.setDragModulationVehicleParams(30, 4.14)

# Set vehicle initial state
vehicle13.setInitialState(1000, -23.67, 14.89, 7.3384, 90.1226, -35.0, 0.0,0.0)
# Propogate a single vehicle trajectory
vehicle13.propogateGuidedEntryD2(0.5,1.0,1.0,6000.0)

# %%
vehicle16A=Vehicle('Titania', 3200.0, 146 , 0.24, np.pi*4.5**2.0, 0.0, 1.125, planet7)
vehicle16A.setInitialState(1000.0,-15.22,75.55,29.2877,88.687,-11.0088 ,0.0,0.0)
vehicle16A.setSolverParams(1E-6)
vehicle16A.propogateEntry (2400.0,0.1,180.0)

# %%
vehicle16B=Vehicle('Titania', 3200.0, 146 , 0.24, np.pi*4.5**2.0, 0.0, 1.125, planet7)
vehicle16B.setInitialState(1000.0,-15.22,75.55,29.2877,88.687,-12.0264 ,0.0,0.0)
vehicle16B.setSolverParams(1E-6)
vehicle16B.propogateEntry (2400.0,0.1,0.0)

# %%
vehicle19A=Vehicle('Titania', 3200.0, 146 , 0.24, np.pi*4.5**2.0, 0.0, 1.125, planet8)
vehicle19A.setInitialState(1000.0,-15.22,75.55,30,8.687, -11.8822 ,0.0,0.0)
vehicle19A.setSolverParams(1E-6)
vehicle19A.propogateEntry (2400.0,0.1,180.0)

# %%
vehicle19B=Vehicle('Titania', 3200.0, 146 , 0.24, np.pi*4.5**2.0, 0.0, 1.125, planet8)
vehicle19B.setInitialState(1000.0,-15.22,75.55,30,8.687, -12.6975 ,0.0,0.0)
vehicle19B.setSolverParams(1E-6)
vehicle19B.propogateEntry (2400.0,0.1,0.0)

# %%
plt.figure(figsize=(11.25, 3.75))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(vehicle1.stag_pres_atm_full, vehicle1.q_stag_total_full, color='xkcd:burnt orange', linestyle='solid', linewidth=1.5, label='Venus drag mod.')
plt.plot(vehicle4.stag_pres_atm_full, vehicle4.q_stag_total_full, color='xkcd:blue', linestyle='solid', linewidth=1.5, label='Earth drag mod.')
plt.plot(vehicle7.stag_pres_atm_full, vehicle7.q_stag_total_full, color='xkcd:red', linestyle='solid', linewidth=1.5, label='Mars drag mod.')
plt.plot(vehicle13.stag_pres_atm_full, vehicle13.q_stag_total_full, color='xkcd:fuchsia', linestyle='solid', linewidth=1.5, label='Titan drag mod.')


plt.xlabel('Stagnation pressure, atm',fontsize=14)
plt.ylabel('Heat rate, '+r'$W/cm^2$',fontsize=14)
ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=14)
ax.tick_params(axis='y',labelsize=14)

plt.grid(linestyle='dotted', linewidth=0.5)
plt.legend(loc='lower right', fontsize=14)

plt.savefig('../thermal-protection-systems-plots/combined-aerocapture-drag-mod.png', dpi= 300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(11.25, 3.75))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(vehicle16A.stag_pres_atm, vehicle16A.q_stag_total, color='xkcd:green blue', linestyle='dashed', linewidth=1.5, label='Uranus overshoot')
plt.plot(vehicle16B.stag_pres_atm, vehicle16B.q_stag_total, color='xkcd:green blue', linestyle='solid', linewidth=1.5, label='Uranus underhsoot')

plt.plot(vehicle19A.stag_pres_atm, vehicle19A.q_stag_total, color='xkcd:blue violet', linestyle='dashed', linewidth=1.5, label='Neptune overshoot')
plt.plot(vehicle19B.stag_pres_atm, vehicle19B.q_stag_total, color='xkcd:blue violet', linestyle='solid', linewidth=1.5, label='Neptune underhsoot')

plt.xlabel('Stagnation pressure, atm',fontsize=14)
plt.ylabel('Heat rate, '+r'$W/cm^2$',fontsize=14)
ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=14)
ax.tick_params(axis='y',labelsize=14)

plt.grid(linestyle='dotted', linewidth=0.5)
plt.legend(loc='lower right', fontsize=14)

plt.savefig('../thermal-protection-systems-plots/combined-aerocapture-uranus-neptune.png', dpi= 300, bbox_inches='tight')
plt.show()
