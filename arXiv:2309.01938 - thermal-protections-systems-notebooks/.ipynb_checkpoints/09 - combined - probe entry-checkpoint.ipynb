# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a planet objecta
planet1=Planet("VENUS")
planet1.h_skip = 150000.0
planet1.h_trap = 20E3
planet1.loadAtmosphereModel('../atmdata/venus-gram-avg.dat', 0 , 1 ,2, 3)

planet2=Planet("EARTH")
planet2.h_skip = 120000.0
planet2.loadAtmosphereModel('../atmdata/earth-gram-avg.dat', 0 , 1 ,2, 3)

planet3 = Planet('MARS')
planet3.loadAtmosphereModel('../atmdata/mars-gram-avg.dat', 0 , 1 ,2, 3)
planet3.h_skip = 120.0E3
planet3.h_trap = 0E3

planet4=Planet("JUPITER")
planet4.h_skip = 1000E3
planet4.h_trap =  0.0E3
planet4.loadAtmosphereModel('../atmdata/jupiter-galileo-asi.dat', 0 , 1 , 2, 3, heightInKmFlag=True)

planet5=Planet("SATURN")
planet5.h_skip = 1000E3
planet5.h_trap =  0.0E3
planet5.loadAtmosphereModel('../atmdata/saturn-nominal.dat', 0 , 1 , 2, 3, heightInKmFlag=True)

planet6 = Planet('TITAN')
planet6.loadAtmosphereModel('../atmdata/titan-gram-avg.dat', 0 , 1 ,2, 3)
planet6.h_skip = 1000.0E3

planet7=Planet("URANUS")
planet7.h_skip = 1000e3
planet7.loadAtmosphereModel('../atmdata/uranus-gram-avg.dat', 0 , 1 ,2, 3, heightInKmFlag=True)
planet7.h_low = 120e3
planet7.h_trap= 0e3

planet8=Planet("NEPTUNE")
planet8.h_skip = 1000e3
planet8.loadAtmosphereModel('../atmdata/neptune-gram-avg.dat', 0 , 7 ,6, 5 , heightInKmFlag=True)
planet8.h_low = 120e3
planet8.h_trap= 0e3

# %%
vehicle2 = Vehicle('PVenus', 91, 190.0, 0.0, np.pi*0.76**2.0*0.25, 0.0, 0.19, planet1)
vehicle2.setInitialState(150,0.0,0.0,11.5,0.0,-10.0,0.0,0.0)
vehicle2.setSolverParams(1E-6)
vehicle2.propogateEntry (1.0*60, 0.1, 0.0)

# %%
vehicle3 = Vehicle('PVenus', 91, 190.0, 0.0, np.pi*0.76**2.0*0.25, 0.0, 0.19, planet1)
vehicle3.setInitialState(150,0.0,0.0,11.5,0.0,-30.0,0.0,0.0)
vehicle3.setSolverParams(1E-6)
vehicle3.propogateEntry (0.5*60, 0.1, 0.0)

# %%
vehicle5 = Vehicle('PVenus', 91, 190.0, 0.0, np.pi*0.76**2.0*0.25, 0.0, 0.19, planet2)
vehicle5.setInitialState(120,0.0,0.0,11.0,0.0,-8.0,0.0,0.0)
vehicle5.setSolverParams(1E-6)
vehicle5.propogateEntry (2.0*60, 0.1, 0.0)

# %%
vehicle6 = Vehicle('PVenus', 91, 190.0, 0.0, np.pi*0.76**2.0*0.25, 0.0, 0.19, planet2)
vehicle6.setInitialState(120,0.0,0.0,11.0,0.0,-15.0,0.0,0.0)
vehicle6.setSolverParams(1E-6)
vehicle6.propogateEntry (1.0*60, 0.1, 0.0)

# %%
vehicle8=Vehicle('MSL', 3257, 146, 0.0, np.pi*4.5**2.0*0.25, 0.0, 1.125, planet3)
vehicle8.setInitialState(120,0.0,0.0,5.25,0.0,-12,0.0,0.0)
vehicle8.setSolverParams(1E-6)
vehicle8.propogateEntry (20*60, 0.1, 0.0)

# %%
vehicle9=Vehicle('MSL', 3257, 146, 0.0, np.pi*4.5**2.0*0.25, 0.0, 1.125, planet3)
vehicle9.setInitialState(120,0.0,0.0,5.25,0.0,-16,0.0,0.0)
vehicle9.setSolverParams(1E-6)
vehicle9.propogateEntry(20*60, 0.1, 0.0)

# %%
vehicle10=Vehicle('Galileo', 340, 267, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.22, planet4)
vehicle10.setInitialState(450,0.0,0.0,47.4,0.0,-8.00,0.0,0.0)
vehicle10.setSolverParams(1E-6)
vehicle10.propogateEntry (2*60, 0.1, 0.0)

# %%
vehicle11=Vehicle('Galileo', 1000, 267, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.22, planet5)
vehicle11.setInitialState(1000,0.0,0.0,36,0.0,-12,0.0,0.0)
vehicle11.setSolverParams(1E-6)
vehicle11.propogateEntry (5*60, 0.1, 0.0)

# %%
vehicle12=Vehicle('Galileo', 1000, 267, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.22, planet5)
vehicle12.setInitialState(1000,0.0,0.0,36,0.0,-18,0.0,0.0)
vehicle12.setSolverParams(1E-6)
vehicle12.propogateEntry (4*60, 0.1, 0.0)

# %%
vehicle15=Vehicle('Huygens', 320, 35, 0.0, np.pi*2.7**2.0*0.25, 0.0, 1.25, planet6)
vehicle15.setInitialState(1000,0.0,0.0,7.0,0.0,-65,0.0,0.0)
vehicle15.setSolverParams(1E-6)
vehicle15.propogateEntry (3*60, 1.0, 0.0)

# %%
vehicle17=Vehicle('UOP', 268, 200, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.40, planet7)
vehicle17.setInitialState(1000,0.0,0.0,23,0.0,-30,0.0,0.0)
vehicle17.setSolverParams(1E-6)
vehicle17.propogateEntry(2*60, 0.1, 0.0)

# %%
vehicle18=Vehicle('UOP', 268, 200, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.40, planet7)
vehicle18.setInitialState(1000,0.0,0.0,23,0.0,-50,0.0,0.0)
vehicle18.setSolverParams(1E-6)
vehicle18.propogateEntry(2*60, 0.1, 0.0)

# %%
vehicle20=Vehicle('UOP', 268, 200, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.40, planet8)
vehicle20.setInitialState(1000,0.0,0.0,25,0.0,-30,0.0,0.0)
vehicle20.setSolverParams(1E-6)
vehicle20.propogateEntry(2*60, 0.1, 0.0)

# %%
vehicle21=Vehicle('UOP', 268, 200, 0.0, np.pi*1.26**2.0*0.25, 0.0, 0.40, planet8)
vehicle21.setInitialState(1000,0.0,0.0,25,0.0,-40,0.0,0.0)
vehicle21.setSolverParams(1E-6)
vehicle21.propogateEntry(2*60, 0.1, 0.0)

# %%
plt.figure(figsize=(8.25, 6.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(vehicle2.stag_pres_atm, vehicle2.q_stag_total, color='xkcd:burnt orange', linestyle='dashed', linewidth=1.5, label='Venus, ' +r'$\gamma = -10$')
plt.plot(vehicle3.stag_pres_atm, vehicle3.q_stag_total, color='xkcd:burnt orange', linestyle='solid', linewidth=1.5, label='Venus, ' +r'$\gamma = -30$')

plt.plot(vehicle5.stag_pres_atm, vehicle5.q_stag_total, color='xkcd:blue', linestyle='dashed', linewidth=1.5, label='Earth, ' +r'$\gamma = -8$')
plt.plot(vehicle6.stag_pres_atm, vehicle6.q_stag_total, color='xkcd:blue', linestyle='solid', linewidth=1.5, label='Earth, ' +r'$\gamma = -15$')

plt.plot(vehicle8.stag_pres_atm, vehicle8.q_stag_total, color='xkcd:red', linestyle='dashed', linewidth=1.5, label='Mars, ' +r'$\gamma = -12$')
plt.plot(vehicle9.stag_pres_atm, vehicle9.q_stag_total, color='xkcd:red', linestyle='solid', linewidth=1.5, label='Mars, ' +r'$\gamma = -16$')

plt.plot(vehicle10.stag_pres_atm, vehicle10.q_stag_total, color='xkcd:black', linestyle='solid', linewidth=1.5, label='Jupiter, ' +r'$\gamma = -8$')

plt.plot(vehicle11.stag_pres_atm, vehicle11.q_stag_total, color='xkcd:dark yellow', linestyle='dashed', linewidth=1.5, label='Saturn, ' +r'$\gamma = -12$')
plt.plot(vehicle12.stag_pres_atm, vehicle12.q_stag_total, color='xkcd:dark yellow', linestyle='solid', linewidth=1.5, label='Saturn, ' +r'$\gamma = -18$')

plt.plot(vehicle15.stag_pres_atm, vehicle15.q_stag_total, color='xkcd:fuchsia', linestyle='solid', linewidth=1.5, label='Titan, ' +r'$\gamma = -65$')

plt.plot(vehicle17.stag_pres_atm, vehicle17.q_stag_total, color='xkcd:green blue', linestyle='dashed', linewidth=1.5, label='Uranus, ' +r'$\gamma = -30$')
plt.plot(vehicle18.stag_pres_atm, vehicle18.q_stag_total, color='xkcd:green blue', linestyle='solid', linewidth=1.5, label='Uranus, ' +r'$\gamma = -50$')

plt.plot(vehicle20.stag_pres_atm, vehicle20.q_stag_total, color='xkcd:blue violet', linestyle='dashed', linewidth=1.5, label='Neptune, ' +r'$\gamma = -30$')
plt.plot(vehicle21.stag_pres_atm, vehicle21.q_stag_total, color='xkcd:blue violet', linestyle='solid', linewidth=1.5, label='Neptune, ' +r'$\gamma = -40$')

plt.xlabel('Stagnation pressure, atm',fontsize=14)
plt.ylabel('Heat rate, '+r'$W/cm^2$',fontsize=14)
ax=plt.gca()
ax.set_yscale('log')
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=14)
ax.tick_params(axis='y',labelsize=14)

plt.grid(linestyle='dotted', linewidth=0.5)
plt.legend(loc=(1.04, 0.08), fontsize=14)
plt.ylim([1, 1E5])

plt.savefig('../thermal-protection-systems-plots/combined-probe-entry-all.png', dpi= 300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8.25, 6.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(vehicle2.stag_pres_atm, vehicle2.q_stag_total, color='xkcd:burnt orange', linestyle='dashed', linewidth=1.5, label='Venus, ' +r'$\gamma = -10$')
plt.plot(vehicle3.stag_pres_atm, vehicle3.q_stag_total, color='xkcd:burnt orange', linestyle='solid', linewidth=1.5, label='Venus, ' +r'$\gamma = -30$')

plt.plot(vehicle5.stag_pres_atm, vehicle5.q_stag_total, color='xkcd:fuchsia', linestyle='dashed', linewidth=1.5, label='Earth, ' +r'$\gamma = -8$')
plt.plot(vehicle6.stag_pres_atm, vehicle6.q_stag_total, color='xkcd:fuchsia', linestyle='solid', linewidth=1.5, label='Earth, ' +r'$\gamma = -15$')

plt.plot(vehicle8.stag_pres_atm, vehicle8.q_stag_total, color='xkcd:red', linestyle='dashed', linewidth=1.5, label='Mars, ' +r'$\gamma = -12$')
plt.plot(vehicle9.stag_pres_atm, vehicle9.q_stag_total, color='xkcd:red', linestyle='solid', linewidth=1.5, label='Mars, ' +r'$\gamma = -16$')

plt.plot(vehicle17.stag_pres_atm, vehicle17.q_stag_total, color='xkcd:green blue', linestyle='dashed', linewidth=1.5, label='Uranus, ' +r'$\gamma = -30$')
plt.plot(vehicle18.stag_pres_atm, vehicle18.q_stag_total, color='xkcd:green blue', linestyle='solid', linewidth=1.5, label='Uranus, ' +r'$\gamma = -50$')

plt.plot(vehicle20.stag_pres_atm, vehicle20.q_stag_total, color='xkcd:blue violet', linestyle='dashed', linewidth=1.5, label='Neptune, ' +r'$\gamma = -30$')
plt.plot(vehicle21.stag_pres_atm, vehicle21.q_stag_total, color='xkcd:blue violet', linestyle='solid', linewidth=1.5, label='Neptune, ' +r'$\gamma = -40$')


plt.xlabel('Stagnation pressure, atm',fontsize=14)
plt.ylabel('Heat rate, '+r'$W/cm^2$',fontsize=14)
ax=plt.gca()
ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=14)
ax.tick_params(axis='y',labelsize=14)

plt.grid(linestyle='dotted', linewidth=0.5)
plt.legend(loc=(1.04, 0.08), fontsize=14)
plt.ylim([1, 5000])

plt.text(5, 3800, "HEEET tested limit", fontsize=12)
plt.scatter(5, 3600, marker="*", s=200, color='xkcd:bright red', zorder=100)

plt.savefig('../thermal-protection-systems-plots/combined-probe-venus-uranus-neptune.png', dpi= 300, bbox_inches='tight')
plt.show()
