# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set up the planet and atmosphere model.
planet=Planet("MARS")
planet.h_skip = 120E3
planet.h_trap =  0.0E3
planet.loadAtmosphereModel('../atmdata/mars-gram-avg.dat', 0 , 1 , 2, 3)

# %%
speedRange = np.linspace(5, 7, 10)
gammaRange = np.linspace(-30, -14, 10)

acc_net_g_max_array       = np.zeros((len(speedRange),len(gammaRange)))
q_stag_total_max_array    = np.zeros((len(speedRange),len(gammaRange)))
heatload_max_array        = np.zeros((len(speedRange),len(gammaRange)))
dyn_pres_array            = np.zeros((len(speedRange),len(gammaRange)))
n = 0

for i, speed in enumerate(speedRange):
    for j, gamma in enumerate(gammaRange):
        vehicle=Vehicle('MSL', 3257, 146, 0.0, np.pi*4.5**2.0*0.25, 0.0, 1.125, planet)
        vehicle.setInitialState(120,0.0,0.0,speed,0.0,gamma,0.0,0.0)
        vehicle.setSolverParams(1E-6)
        vehicle.propogateEntry (20*60, 0.1, 0.0)
        n+=1
        print("n = " + str(n) +"G_MAX: "+str("{:.2f}".format(max(vehicle.acc_net_g)))+", Q_MAX: "+str("{:.2f}".format(max(vehicle.q_stag_total)))+", J_MAX: "+str("{:.2f}".format(max(vehicle.heatload/1.0E3)))+", P_MAX: "+str("{:.2f}".format(max(vehicle.dyn_pres_atm))))

        acc_net_g_max_array[i,j]     = max(vehicle.acc_net_g)
        q_stag_total_max_array[i,j]  = max(vehicle.q_stag_total)
        heatload_max_array[i,j]      = max(vehicle.heatload/1.0E3)
        dyn_pres_array[i,j]         = max(vehicle.dyn_pres_atm)
# Out:
# n = 1G_MAX: 22.79, Q_MAX: 71.07, J_MAX: 1.30, P_MAX: 0.32
# n = 2G_MAX: 21.53, Q_MAX: 69.01, J_MAX: 1.35, P_MAX: 0.30
# n = 3G_MAX: 20.18, Q_MAX: 66.77, J_MAX: 1.40, P_MAX: 0.29
# n = 4G_MAX: 18.74, Q_MAX: 64.34, J_MAX: 1.46, P_MAX: 0.26
# n = 5G_MAX: 17.27, Q_MAX: 61.77, J_MAX: 1.53, P_MAX: 0.24
# n = 6G_MAX: 15.76, Q_MAX: 59.02, J_MAX: 1.61, P_MAX: 0.22
# n = 7G_MAX: 14.21, Q_MAX: 56.04, J_MAX: 1.70, P_MAX: 0.20
# n = 8G_MAX: 12.56, Q_MAX: 52.76, J_MAX: 1.81, P_MAX: 0.18
# n = 9G_MAX: 10.74, Q_MAX: 48.99, J_MAX: 1.95, P_MAX: 0.15
# n = 10G_MAX: 8.80, Q_MAX: 44.66, J_MAX: 2.14, P_MAX: 0.12
# n = 11G_MAX: 24.71, Q_MAX: 80.56, J_MAX: 1.42, P_MAX: 0.35
# n = 12G_MAX: 23.32, Q_MAX: 78.21, J_MAX: 1.47, P_MAX: 0.33
# n = 13G_MAX: 21.84, Q_MAX: 75.64, J_MAX: 1.53, P_MAX: 0.31
# n = 14G_MAX: 20.26, Q_MAX: 72.85, J_MAX: 1.59, P_MAX: 0.29
# n = 15G_MAX: 18.65, Q_MAX: 69.91, J_MAX: 1.67, P_MAX: 0.26
# n = 16G_MAX: 16.99, Q_MAX: 66.76, J_MAX: 1.76, P_MAX: 0.24
# n = 17G_MAX: 15.29, Q_MAX: 63.33, J_MAX: 1.86, P_MAX: 0.22
# n = 18G_MAX: 13.46, Q_MAX: 59.53, J_MAX: 1.98, P_MAX: 0.19
# n = 19G_MAX: 11.45, Q_MAX: 55.15, J_MAX: 2.14, P_MAX: 0.16
# n = 20G_MAX: 9.29, Q_MAX: 50.11, J_MAX: 2.36, P_MAX: 0.13
# n = 21G_MAX: 26.71, Q_MAX: 90.88, J_MAX: 1.54, P_MAX: 0.38
# n = 22G_MAX: 25.20, Q_MAX: 88.20, J_MAX: 1.60, P_MAX: 0.36
# n = 23G_MAX: 23.58, Q_MAX: 85.28, J_MAX: 1.66, P_MAX: 0.33
# n = 24G_MAX: 21.85, Q_MAX: 82.11, J_MAX: 1.73, P_MAX: 0.31
# n = 25G_MAX: 20.10, Q_MAX: 78.76, J_MAX: 1.82, P_MAX: 0.28
# n = 26G_MAX: 18.28, Q_MAX: 75.16, J_MAX: 1.91, P_MAX: 0.26
# n = 27G_MAX: 16.42, Q_MAX: 71.25, J_MAX: 2.03, P_MAX: 0.23
# n = 28G_MAX: 14.40, Q_MAX: 66.88, J_MAX: 2.16, P_MAX: 0.20
# n = 29G_MAX: 12.18, Q_MAX: 61.83, J_MAX: 2.34, P_MAX: 0.17
# n = 30G_MAX: 9.78, Q_MAX: 56.00, J_MAX: 2.59, P_MAX: 0.14
# n = 31G_MAX: 28.80, Q_MAX: 102.06, J_MAX: 1.67, P_MAX: 0.41
# n = 32G_MAX: 27.15, Q_MAX: 99.04, J_MAX: 1.73, P_MAX: 0.38
# n = 33G_MAX: 25.39, Q_MAX: 95.73, J_MAX: 1.80, P_MAX: 0.36
# n = 34G_MAX: 23.51, Q_MAX: 92.13, J_MAX: 1.88, P_MAX: 0.33
# n = 35G_MAX: 21.60, Q_MAX: 88.34, J_MAX: 1.97, P_MAX: 0.31
# n = 36G_MAX: 19.62, Q_MAX: 84.27, J_MAX: 2.08, P_MAX: 0.28
# n = 37G_MAX: 17.59, Q_MAX: 79.82, J_MAX: 2.20, P_MAX: 0.25
# n = 38G_MAX: 15.37, Q_MAX: 74.83, J_MAX: 2.35, P_MAX: 0.22
# n = 39G_MAX: 12.94, Q_MAX: 69.05, J_MAX: 2.55, P_MAX: 0.18
# n = 40G_MAX: 10.28, Q_MAX: 62.34, J_MAX: 2.83, P_MAX: 0.15
# n = 41G_MAX: 30.97, Q_MAX: 114.14, J_MAX: 1.80, P_MAX: 0.44
# n = 42G_MAX: 29.18, Q_MAX: 110.74, J_MAX: 1.87, P_MAX: 0.41
# n = 43G_MAX: 27.27, Q_MAX: 107.00, J_MAX: 1.95, P_MAX: 0.39
# n = 44G_MAX: 25.23, Q_MAX: 102.96, J_MAX: 2.03, P_MAX: 0.36
# n = 45G_MAX: 23.17, Q_MAX: 98.69, J_MAX: 2.13, P_MAX: 0.33
# n = 46G_MAX: 21.02, Q_MAX: 94.09, J_MAX: 2.24, P_MAX: 0.30
# n = 47G_MAX: 18.81, Q_MAX: 89.06, J_MAX: 2.38, P_MAX: 0.27
# n = 48G_MAX: 16.38, Q_MAX: 83.40, J_MAX: 2.55, P_MAX: 0.23
# n = 49G_MAX: 13.73, Q_MAX: 76.83, J_MAX: 2.77, P_MAX: 0.19
# n = 50G_MAX: 10.80, Q_MAX: 69.15, J_MAX: 3.08, P_MAX: 0.15
# n = 51G_MAX: 33.22, Q_MAX: 127.15, J_MAX: 1.94, P_MAX: 0.47
# n = 52G_MAX: 31.29, Q_MAX: 123.33, J_MAX: 2.01, P_MAX: 0.44
# n = 53G_MAX: 29.22, Q_MAX: 119.15, J_MAX: 2.10, P_MAX: 0.41
# n = 54G_MAX: 27.03, Q_MAX: 114.62, J_MAX: 2.19, P_MAX: 0.38
# n = 55G_MAX: 24.79, Q_MAX: 109.84, J_MAX: 2.30, P_MAX: 0.35
# n = 56G_MAX: 22.47, Q_MAX: 104.66, J_MAX: 2.42, P_MAX: 0.32
# n = 57G_MAX: 20.08, Q_MAX: 99.01, J_MAX: 2.57, P_MAX: 0.28
# n = 58G_MAX: 17.42, Q_MAX: 92.63, J_MAX: 2.75, P_MAX: 0.25
# n = 59G_MAX: 14.55, Q_MAX: 85.20, J_MAX: 2.99, P_MAX: 0.21
# n = 60G_MAX: 11.33, Q_MAX: 76.43, J_MAX: 3.35, P_MAX: 0.16
# n = 61G_MAX: 35.56, Q_MAX: 141.13, J_MAX: 2.08, P_MAX: 0.50
# n = 62G_MAX: 33.48, Q_MAX: 136.87, J_MAX: 2.16, P_MAX: 0.47
# n = 63G_MAX: 31.24, Q_MAX: 132.19, J_MAX: 2.25, P_MAX: 0.44
# n = 64G_MAX: 28.88, Q_MAX: 127.16, J_MAX: 2.35, P_MAX: 0.41
# n = 65G_MAX: 26.48, Q_MAX: 121.81, J_MAX: 2.47, P_MAX: 0.37
# n = 66G_MAX: 23.98, Q_MAX: 116.03, J_MAX: 2.60, P_MAX: 0.34
# n = 67G_MAX: 21.39, Q_MAX: 109.69, J_MAX: 2.76, P_MAX: 0.30
# n = 68G_MAX: 18.51, Q_MAX: 102.52, J_MAX: 2.96, P_MAX: 0.26
# n = 69G_MAX: 15.40, Q_MAX: 94.17, J_MAX: 3.23, P_MAX: 0.22
# n = 70G_MAX: 11.87, Q_MAX: 84.21, J_MAX: 3.62, P_MAX: 0.17
# n = 71G_MAX: 37.98, Q_MAX: 156.11, J_MAX: 2.23, P_MAX: 0.54
# n = 72G_MAX: 35.75, Q_MAX: 151.38, J_MAX: 2.32, P_MAX: 0.51
# n = 73G_MAX: 33.34, Q_MAX: 146.19, J_MAX: 2.41, P_MAX: 0.47
# n = 74G_MAX: 30.81, Q_MAX: 140.57, J_MAX: 2.52, P_MAX: 0.44
# n = 75G_MAX: 28.23, Q_MAX: 134.63, J_MAX: 2.65, P_MAX: 0.40
# n = 76G_MAX: 25.54, Q_MAX: 128.20, J_MAX: 2.79, P_MAX: 0.36
# n = 77G_MAX: 22.75, Q_MAX: 121.13, J_MAX: 2.96, P_MAX: 0.32
# n = 78G_MAX: 19.64, Q_MAX: 113.11, J_MAX: 3.18, P_MAX: 0.28
# n = 79G_MAX: 16.27, Q_MAX: 103.77, J_MAX: 3.47, P_MAX: 0.23
# n = 80G_MAX: 12.42, Q_MAX: 92.50, J_MAX: 3.91, P_MAX: 0.18
# n = 81G_MAX: 40.49, Q_MAX: 172.14, J_MAX: 2.38, P_MAX: 0.57
# n = 82G_MAX: 38.09, Q_MAX: 166.90, J_MAX: 2.47, P_MAX: 0.54
# n = 83G_MAX: 35.51, Q_MAX: 161.13, J_MAX: 2.58, P_MAX: 0.50
# n = 84G_MAX: 32.80, Q_MAX: 154.93, J_MAX: 2.69, P_MAX: 0.46
# n = 85G_MAX: 30.03, Q_MAX: 148.34, J_MAX: 2.83, P_MAX: 0.42
# n = 86G_MAX: 27.15, Q_MAX: 141.21, J_MAX: 2.99, P_MAX: 0.38
# n = 87G_MAX: 24.16, Q_MAX: 133.37, J_MAX: 3.17, P_MAX: 0.34
# n = 88G_MAX: 20.80, Q_MAX: 124.42, J_MAX: 3.41, P_MAX: 0.29
# n = 89G_MAX: 17.18, Q_MAX: 114.01, J_MAX: 3.73, P_MAX: 0.24
# n = 90G_MAX: 13.00, Q_MAX: 101.32, J_MAX: 4.21, P_MAX: 0.18
# n = 91G_MAX: 43.08, Q_MAX: 189.23, J_MAX: 2.54, P_MAX: 0.61
# n = 92G_MAX: 40.51, Q_MAX: 183.45, J_MAX: 2.64, P_MAX: 0.57
# n = 93G_MAX: 37.76, Q_MAX: 177.09, J_MAX: 2.75, P_MAX: 0.53
# n = 94G_MAX: 34.86, Q_MAX: 170.23, J_MAX: 2.88, P_MAX: 0.49
# n = 95G_MAX: 31.90, Q_MAX: 162.97, J_MAX: 3.02, P_MAX: 0.45
# n = 96G_MAX: 28.82, Q_MAX: 155.08, J_MAX: 3.19, P_MAX: 0.41
# n = 97G_MAX: 25.61, Q_MAX: 146.41, J_MAX: 3.39, P_MAX: 0.36
# n = 98G_MAX: 22.01, Q_MAX: 136.48, J_MAX: 3.64, P_MAX: 0.31
# n = 99G_MAX: 18.12, Q_MAX: 124.92, J_MAX: 3.99, P_MAX: 0.26
# n = 100G_MAX: 13.59, Q_MAX: 110.68, J_MAX: 4.52, P_MAX: 0.19

# %%
from scipy import interpolate

# %%
f1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(acc_net_g_max_array), kind='cubic')
q1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(q_stag_total_max_array), kind='cubic')
h1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(heatload_max_array), kind='cubic')
s1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(dyn_pres_array), kind='cubic')

x_new = np.linspace(5, 7, 100)
y_new = np.linspace(-30, -14, 100)


g1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
h1_new =  np.zeros((len(x_new),len(y_new)))
s1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        g1_new[i,j] = f1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        h1_new[i,j] = h1(x_new[i],y_new[j])
        s1_new[i,j] = s1(x_new[i],y_new[j])

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()
fig.set_size_inches([8, 8])
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

GCS1 = plt.contour(Y, X, np.transpose(g1_new), levels=15, linewidths=2.0, colors='black')
plt.clabel(GCS1, inline=1, fontsize=14, colors='black',fmt='%3d',inline_spacing=1)
#GCS1.collections[0].set_label(r'g-load')

QCS1 = plt.contour(Y, X, np.transpose(q1_new),  levels=15, linewidths=2.0, colors='red')
plt.clabel(QCS1, inline=1, fontsize=14, colors='red',fmt='%3d',inline_spacing=1)
#QCS1.collections[0].set_label(r'$\dot{q}$'+', '+r'$W/cm^2$')

HCS1 = plt.contour(Y, X, np.transpose(h1_new), levels=15, linewidths=2.0, colors='magenta')
plt.clabel(HCS1, inline=1, fontsize=14, colors='magenta',fmt='%0.1f',inline_spacing=1)
#HCS1.collections[0].set_label(r'$Q$'+', '+r'$kJ/cm^2$')

plt.xlabel("Planet relative EFPA "+r'$\gamma_e$'+r', deg' ,fontsize=16)
plt.ylabel(r'Entry speed, km/s' ,fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')


ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')

ax.xaxis.set_tick_params(width=2, length=8)
ax.yaxis.set_tick_params(width=2, length=8)

ax.xaxis.set_tick_params(width=1, length=6, which='minor')
ax.yaxis.set_tick_params(width=1, length=6, which='minor')


ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

h1,l1 = GCS1.legend_elements()
h2,l1 = QCS1.legend_elements()
h3,l1 = HCS1.legend_elements()

plt.legend([h1[0], h2[0], h3[0]], ['g-load', r'$\dot{q}$'+', '+r'$W/cm^2$', r'$Q$'+', '+r'$kJ/cm^2$'], 
           fontsize=14, loc='lower left', framealpha=1.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.scatter(-16.18, 5.3, marker="D", s=30, color='xkcd:green', zorder=2)
plt.annotate("Mars 2020", xy=(-16.18, 5.3), xytext=(-18.18, 5.4), va="center", ha="center",
            arrowprops=dict(arrowstyle='->, head_width=0.2', facecolor='blue'), 
            fontsize=14, color='b', bbox=dict(boxstyle='round,pad=0.2', fc='w', ec='k', alpha=1.0))


plt.savefig('../plots/mars-lander-entry.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
speedRange = np.linspace(5, 7, 10)
gammaRange = np.linspace(-30, -12, 10)

acc_net_g_max_array       = np.zeros((len(speedRange),len(gammaRange)))
q_stag_total_max_array    = np.zeros((len(speedRange),len(gammaRange)))
heatload_max_array        = np.zeros((len(speedRange),len(gammaRange)))
dyn_pres_array            = np.zeros((len(speedRange),len(gammaRange)))
n = 0

for i, speed in enumerate(speedRange):
    for j, gamma in enumerate(gammaRange):
        vehicle=Vehicle('ADEPT', 50, 25.0, 0.0, np.pi*1.5**2.0*0.25, 0.0, 0.20, planet)
        vehicle.setInitialState(120,0.0,0.0,speed,0.0,gamma,0.0,0.0)
        vehicle.setSolverParams(1E-6)
        vehicle.propogateEntry (20*60, 0.1, 0.0)
        n+=1
        print("n = " + str(n) +"G_MAX: "+str("{:.2f}".format(max(vehicle.acc_net_g)))+", Q_MAX: "+str("{:.2f}".format(max(vehicle.q_stag_total)))+", J_MAX: "+str("{:.2f}".format(max(vehicle.heatload/1.0E3)))+", P_MAX: "+str("{:.2f}".format(max(vehicle.dyn_pres_atm))))

        acc_net_g_max_array[i,j]     = max(vehicle.acc_net_g)
        q_stag_total_max_array[i,j]  = max(vehicle.q_stag_total)
        heatload_max_array[i,j]      = max(vehicle.heatload/1.0E3)
        dyn_pres_array[i,j]         = max(vehicle.dyn_pres_atm)
# Out:
# n = 1G_MAX: 26.32, Q_MAX: 73.51, J_MAX: 1.27, P_MAX: 0.06
# n = 2G_MAX: 24.63, Q_MAX: 70.96, J_MAX: 1.31, P_MAX: 0.06
# n = 3G_MAX: 22.88, Q_MAX: 68.29, J_MAX: 1.36, P_MAX: 0.06
# n = 4G_MAX: 21.10, Q_MAX: 65.52, J_MAX: 1.42, P_MAX: 0.05
# n = 5G_MAX: 19.28, Q_MAX: 62.53, J_MAX: 1.48, P_MAX: 0.05
# n = 6G_MAX: 17.43, Q_MAX: 59.31, J_MAX: 1.56, P_MAX: 0.04
# n = 7G_MAX: 15.41, Q_MAX: 55.81, J_MAX: 1.66, P_MAX: 0.04
# n = 8G_MAX: 13.08, Q_MAX: 51.82, J_MAX: 1.79, P_MAX: 0.03
# n = 9G_MAX: 10.60, Q_MAX: 46.91, J_MAX: 1.97, P_MAX: 0.03
# n = 10G_MAX: 7.89, Q_MAX: 40.95, J_MAX: 2.24, P_MAX: 0.02
# n = 11G_MAX: 28.55, Q_MAX: 83.39, J_MAX: 1.38, P_MAX: 0.07
# n = 12G_MAX: 26.71, Q_MAX: 80.47, J_MAX: 1.43, P_MAX: 0.06
# n = 13G_MAX: 24.80, Q_MAX: 77.43, J_MAX: 1.48, P_MAX: 0.06
# n = 14G_MAX: 22.85, Q_MAX: 74.26, J_MAX: 1.54, P_MAX: 0.06
# n = 15G_MAX: 20.85, Q_MAX: 70.83, J_MAX: 1.62, P_MAX: 0.05
# n = 16G_MAX: 18.83, Q_MAX: 67.14, J_MAX: 1.71, P_MAX: 0.05
# n = 17G_MAX: 16.58, Q_MAX: 63.12, J_MAX: 1.82, P_MAX: 0.04
# n = 18G_MAX: 14.00, Q_MAX: 58.49, J_MAX: 1.96, P_MAX: 0.03
# n = 19G_MAX: 11.25, Q_MAX: 52.77, J_MAX: 2.17, P_MAX: 0.03
# n = 20G_MAX: 8.23, Q_MAX: 45.76, J_MAX: 2.48, P_MAX: 0.02
# n = 21G_MAX: 30.89, Q_MAX: 94.11, J_MAX: 1.50, P_MAX: 0.07
# n = 22G_MAX: 28.88, Q_MAX: 90.82, J_MAX: 1.55, P_MAX: 0.07
# n = 23G_MAX: 26.80, Q_MAX: 87.37, J_MAX: 1.61, P_MAX: 0.06
# n = 24G_MAX: 24.67, Q_MAX: 83.76, J_MAX: 1.68, P_MAX: 0.06
# n = 25G_MAX: 22.50, Q_MAX: 79.86, J_MAX: 1.76, P_MAX: 0.05
# n = 26G_MAX: 20.28, Q_MAX: 75.65, J_MAX: 1.86, P_MAX: 0.05
# n = 27G_MAX: 17.80, Q_MAX: 71.06, J_MAX: 1.98, P_MAX: 0.04
# n = 28G_MAX: 14.96, Q_MAX: 65.71, J_MAX: 2.14, P_MAX: 0.04
# n = 29G_MAX: 11.93, Q_MAX: 59.11, J_MAX: 2.37, P_MAX: 0.03
# n = 30G_MAX: 8.57, Q_MAX: 50.93, J_MAX: 2.73, P_MAX: 0.02
# n = 31G_MAX: 33.32, Q_MAX: 105.75, J_MAX: 1.62, P_MAX: 0.08
# n = 32G_MAX: 31.14, Q_MAX: 102.02, J_MAX: 1.68, P_MAX: 0.08
# n = 33G_MAX: 28.88, Q_MAX: 98.13, J_MAX: 1.74, P_MAX: 0.07
# n = 34G_MAX: 26.58, Q_MAX: 94.06, J_MAX: 1.82, P_MAX: 0.06
# n = 35G_MAX: 24.21, Q_MAX: 89.63, J_MAX: 1.91, P_MAX: 0.06
# n = 36G_MAX: 21.79, Q_MAX: 84.86, J_MAX: 2.02, P_MAX: 0.05
# n = 37G_MAX: 19.07, Q_MAX: 79.66, J_MAX: 2.15, P_MAX: 0.05
# n = 38G_MAX: 15.96, Q_MAX: 73.53, J_MAX: 2.33, P_MAX: 0.04
# n = 39G_MAX: 12.63, Q_MAX: 65.96, J_MAX: 2.58, P_MAX: 0.03
# n = 40G_MAX: 8.92, Q_MAX: 56.46, J_MAX: 3.00, P_MAX: 0.02
# n = 41G_MAX: 35.85, Q_MAX: 118.32, J_MAX: 1.75, P_MAX: 0.09
# n = 42G_MAX: 33.49, Q_MAX: 114.13, J_MAX: 1.81, P_MAX: 0.08
# n = 43G_MAX: 31.04, Q_MAX: 109.76, J_MAX: 1.88, P_MAX: 0.08
# n = 44G_MAX: 28.55, Q_MAX: 105.17, J_MAX: 1.96, P_MAX: 0.07
# n = 45G_MAX: 25.98, Q_MAX: 100.19, J_MAX: 2.06, P_MAX: 0.06
# n = 46G_MAX: 23.36, Q_MAX: 94.81, J_MAX: 2.18, P_MAX: 0.06
# n = 47G_MAX: 20.39, Q_MAX: 88.94, J_MAX: 2.33, P_MAX: 0.05
# n = 48G_MAX: 17.00, Q_MAX: 81.95, J_MAX: 2.53, P_MAX: 0.04
# n = 49G_MAX: 13.36, Q_MAX: 73.34, J_MAX: 2.81, P_MAX: 0.03
# n = 50G_MAX: 9.29, Q_MAX: 62.37, J_MAX: 3.28, P_MAX: 0.02
# n = 51G_MAX: 38.48, Q_MAX: 131.86, J_MAX: 1.88, P_MAX: 0.09
# n = 52G_MAX: 35.93, Q_MAX: 127.18, J_MAX: 1.95, P_MAX: 0.09
# n = 53G_MAX: 33.29, Q_MAX: 122.29, J_MAX: 2.03, P_MAX: 0.08
# n = 54G_MAX: 30.61, Q_MAX: 117.14, J_MAX: 2.12, P_MAX: 0.07
# n = 55G_MAX: 27.83, Q_MAX: 111.56, J_MAX: 2.22, P_MAX: 0.07
# n = 56G_MAX: 24.99, Q_MAX: 105.53, J_MAX: 2.35, P_MAX: 0.06
# n = 57G_MAX: 21.76, Q_MAX: 98.92, J_MAX: 2.51, P_MAX: 0.05
# n = 58G_MAX: 18.08, Q_MAX: 91.00, J_MAX: 2.73, P_MAX: 0.04
# n = 59G_MAX: 14.11, Q_MAX: 81.26, J_MAX: 3.04, P_MAX: 0.03
# n = 60G_MAX: 9.66, Q_MAX: 68.65, J_MAX: 3.57, P_MAX: 0.02
# n = 61G_MAX: 41.21, Q_MAX: 146.41, J_MAX: 2.02, P_MAX: 0.10
# n = 62G_MAX: 38.47, Q_MAX: 141.19, J_MAX: 2.09, P_MAX: 0.09
# n = 63G_MAX: 35.62, Q_MAX: 135.75, J_MAX: 2.18, P_MAX: 0.09
# n = 64G_MAX: 32.73, Q_MAX: 130.00, J_MAX: 2.27, P_MAX: 0.08
# n = 65G_MAX: 29.75, Q_MAX: 123.78, J_MAX: 2.39, P_MAX: 0.07
# n = 66G_MAX: 26.69, Q_MAX: 117.04, J_MAX: 2.53, P_MAX: 0.06
# n = 67G_MAX: 23.17, Q_MAX: 109.64, J_MAX: 2.70, P_MAX: 0.06
# n = 68G_MAX: 19.20, Q_MAX: 100.72, J_MAX: 2.94, P_MAX: 0.05
# n = 69G_MAX: 14.89, Q_MAX: 89.74, J_MAX: 3.28, P_MAX: 0.04
# n = 70G_MAX: 10.04, Q_MAX: 75.33, J_MAX: 3.87, P_MAX: 0.02
# n = 71G_MAX: 44.03, Q_MAX: 162.02, J_MAX: 2.17, P_MAX: 0.11
# n = 72G_MAX: 41.09, Q_MAX: 156.21, J_MAX: 2.24, P_MAX: 0.10
# n = 73G_MAX: 38.04, Q_MAX: 150.18, J_MAX: 2.33, P_MAX: 0.09
# n = 74G_MAX: 34.94, Q_MAX: 143.79, J_MAX: 2.44, P_MAX: 0.08
# n = 75G_MAX: 31.74, Q_MAX: 136.87, J_MAX: 2.56, P_MAX: 0.08
# n = 76G_MAX: 28.44, Q_MAX: 129.37, J_MAX: 2.71, P_MAX: 0.07
# n = 77G_MAX: 24.64, Q_MAX: 121.13, J_MAX: 2.90, P_MAX: 0.06
# n = 78G_MAX: 20.36, Q_MAX: 111.13, J_MAX: 3.15, P_MAX: 0.05
# n = 79G_MAX: 15.69, Q_MAX: 98.82, J_MAX: 3.53, P_MAX: 0.04
# n = 80G_MAX: 10.44, Q_MAX: 82.43, J_MAX: 4.19, P_MAX: 0.03
# n = 81G_MAX: 46.95, Q_MAX: 178.69, J_MAX: 2.31, P_MAX: 0.11
# n = 82G_MAX: 43.80, Q_MAX: 172.28, J_MAX: 2.40, P_MAX: 0.11
# n = 83G_MAX: 40.54, Q_MAX: 165.61, J_MAX: 2.49, P_MAX: 0.10
# n = 84G_MAX: 37.22, Q_MAX: 158.54, J_MAX: 2.60, P_MAX: 0.09
# n = 85G_MAX: 33.80, Q_MAX: 150.88, J_MAX: 2.74, P_MAX: 0.08
# n = 86G_MAX: 30.25, Q_MAX: 142.54, J_MAX: 2.90, P_MAX: 0.07
# n = 87G_MAX: 26.16, Q_MAX: 133.41, J_MAX: 3.10, P_MAX: 0.06
# n = 88G_MAX: 21.56, Q_MAX: 122.24, J_MAX: 3.38, P_MAX: 0.05
# n = 89G_MAX: 16.52, Q_MAX: 108.50, J_MAX: 3.79, P_MAX: 0.04
# n = 90G_MAX: 10.85, Q_MAX: 89.95, J_MAX: 4.53, P_MAX: 0.03
# n = 91G_MAX: 49.97, Q_MAX: 196.50, J_MAX: 2.47, P_MAX: 0.12
# n = 92G_MAX: 46.61, Q_MAX: 189.42, J_MAX: 2.56, P_MAX: 0.11
# n = 93G_MAX: 43.12, Q_MAX: 182.07, J_MAX: 2.66, P_MAX: 0.10
# n = 94G_MAX: 39.58, Q_MAX: 174.27, J_MAX: 2.78, P_MAX: 0.10
# n = 95G_MAX: 35.92, Q_MAX: 165.81, J_MAX: 2.92, P_MAX: 0.09
# n = 96G_MAX: 32.12, Q_MAX: 156.61, J_MAX: 3.09, P_MAX: 0.08
# n = 97G_MAX: 27.73, Q_MAX: 146.49, J_MAX: 3.31, P_MAX: 0.07
# n = 98G_MAX: 22.79, Q_MAX: 134.08, J_MAX: 3.61, P_MAX: 0.06
# n = 99G_MAX: 17.38, Q_MAX: 118.82, J_MAX: 4.05, P_MAX: 0.04
# n = 100G_MAX: 11.26, Q_MAX: 97.93, J_MAX: 4.87, P_MAX: 0.03

# %%
f1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(acc_net_g_max_array), kind='cubic')
q1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(q_stag_total_max_array), kind='cubic')
h1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(heatload_max_array), kind='cubic')
s1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(dyn_pres_array), kind='cubic')

x_new = np.linspace(5, 7, 100)
y_new = np.linspace(-30, -12, 100)


g1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
h1_new =  np.zeros((len(x_new),len(y_new)))
s1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        g1_new[i,j] = f1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        h1_new[i,j] = h1(x_new[i],y_new[j])
        s1_new[i,j] = s1(x_new[i],y_new[j])

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()
fig.set_size_inches([8, 8])
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

GCS1 = plt.contour(Y, X, np.transpose(g1_new), levels=15, linewidths=2.0, colors='black')
plt.clabel(GCS1, inline=1, fontsize=14, colors='black',fmt='%3d',inline_spacing=1)
#GCS1.collections[0].set_label(r'g-load')

QCS1 = plt.contour(Y, X, np.transpose(q1_new),  levels=15, linewidths=2.0, colors='red')
plt.clabel(QCS1, inline=1, fontsize=14, colors='red',fmt='%3d',inline_spacing=1)
#QCS1.collections[0].set_label(r'$\dot{q}$'+', '+r'$W/cm^2$')

HCS1 = plt.contour(Y, X, np.transpose(h1_new), levels=15, linewidths=2.0, colors='magenta')
plt.clabel(HCS1, inline=1, fontsize=14, colors='magenta',fmt='%0.1f',inline_spacing=1)
#HCS1.collections[0].set_label(r'$Q$'+', '+r'$kJ/cm^2$')

plt.xlabel("Planet relative EFPA "+r'$\gamma_e$'+r', deg' ,fontsize=16)
plt.ylabel(r'Entry speed, km/s' ,fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')


ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')

ax.xaxis.set_tick_params(width=2, length=8)
ax.yaxis.set_tick_params(width=2, length=8)

ax.xaxis.set_tick_params(width=1, length=6, which='minor')
ax.yaxis.set_tick_params(width=1, length=6, which='minor')


ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

h1,l1 = GCS1.legend_elements()
h2,l1 = QCS1.legend_elements()
h3,l1 = HCS1.legend_elements()

plt.legend([h1[0], h2[0], h3[0]], ['g-load', r'$\dot{q}$'+', '+r'$W/cm^2$', r'$Q$'+', '+r'$kJ/cm^2$'], 
           fontsize=14, loc='lower left', framealpha=1.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)


plt.savefig('../plots/mars-low-bc.png', dpi=300, bbox_inches='tight')
plt.show()
