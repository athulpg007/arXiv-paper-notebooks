# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set up the planet and atmosphere model.
planet=Planet("EARTH")
planet.h_skip = 120E3
planet.h_trap =  0.0E3
planet.loadAtmosphereModel('../atmdata/earth-gram-avg.dat', 0 , 1 , 2, 3)

# %%
speedRange = np.linspace(10, 13, 10)
gammaRange = np.linspace(-30, -7, 10)

acc_net_g_max_array       = np.zeros((len(speedRange),len(gammaRange)))
q_stag_total_max_array    = np.zeros((len(speedRange),len(gammaRange)))
heatload_max_array        = np.zeros((len(speedRange),len(gammaRange)))
dyn_pres_array            = np.zeros((len(speedRange),len(gammaRange)))
n = 0

for i, speed in enumerate(speedRange):
    for j, gamma in enumerate(gammaRange):
        vehicle=Vehicle('Stardust', 46, 60.0, 0.0, np.pi*0.827**2.0*0.25, 0.0, 0.23, planet)
        vehicle.setInitialState(120,0.0,0.0,speed,0.0,gamma,0.0,0.0)
        vehicle.setSolverParams(1E-6)
        vehicle.propogateEntry (20*60, 0.1, 0.0)
        n+=1
        print("n = " + str(n) +"G_MAX: "+str("{:.2f}".format(max(vehicle.acc_net_g)))+", Q_MAX: "+str("{:.2f}".format(max(vehicle.q_stag_total)))+", J_MAX: "+str("{:.2f}".format(max(vehicle.heatload/1.0E3)))+", P_MAX: "+str("{:.2f}".format(max(vehicle.dyn_pres_atm))))

        acc_net_g_max_array[i,j]     = max(vehicle.acc_net_g)
        q_stag_total_max_array[i,j]  = max(vehicle.q_stag_total)
        heatload_max_array[i,j]      = max(vehicle.heatload/1.0E3)
        dyn_pres_array[i,j]         = max(vehicle.dyn_pres_atm)
# Out:
# n = 1G_MAX: 123.25, Q_MAX: 799.59, J_MAX: 6.32, P_MAX: 0.72
# n = 2G_MAX: 112.45, Q_MAX: 765.77, J_MAX: 6.58, P_MAX: 0.65
# n = 3G_MAX: 101.57, Q_MAX: 730.20, J_MAX: 6.89, P_MAX: 0.59
# n = 4G_MAX: 90.59, Q_MAX: 693.23, J_MAX: 7.26, P_MAX: 0.53
# n = 5G_MAX: 79.35, Q_MAX: 653.30, J_MAX: 7.70, P_MAX: 0.46
# n = 6G_MAX: 67.90, Q_MAX: 608.90, J_MAX: 8.25, P_MAX: 0.39
# n = 7G_MAX: 56.49, Q_MAX: 559.84, J_MAX: 8.96, P_MAX: 0.33
# n = 8G_MAX: 45.03, Q_MAX: 504.92, J_MAX: 9.93, P_MAX: 0.26
# n = 9G_MAX: 33.01, Q_MAX: 439.20, J_MAX: 11.40, P_MAX: 0.19
# n = 10G_MAX: 20.19, Q_MAX: 350.22, J_MAX: 14.17, P_MAX: 0.12
# n = 11G_MAX: 131.27, Q_MAX: 894.15, J_MAX: 6.81, P_MAX: 0.76
# n = 12G_MAX: 119.73, Q_MAX: 856.92, J_MAX: 7.09, P_MAX: 0.70
# n = 13G_MAX: 108.10, Q_MAX: 816.71, J_MAX: 7.42, P_MAX: 0.63
# n = 14G_MAX: 96.36, Q_MAX: 773.33, J_MAX: 7.81, P_MAX: 0.56
# n = 15G_MAX: 84.32, Q_MAX: 726.67, J_MAX: 8.29, P_MAX: 0.49
# n = 16G_MAX: 72.06, Q_MAX: 676.43, J_MAX: 8.88, P_MAX: 0.42
# n = 17G_MAX: 59.85, Q_MAX: 621.36, J_MAX: 9.64, P_MAX: 0.35
# n = 18G_MAX: 47.53, Q_MAX: 558.80, J_MAX: 10.70, P_MAX: 0.28
# n = 19G_MAX: 34.57, Q_MAX: 483.53, J_MAX: 12.30, P_MAX: 0.20
# n = 20G_MAX: 20.57, Q_MAX: 381.35, J_MAX: 15.42, P_MAX: 0.12
# n = 21G_MAX: 139.56, Q_MAX: 1017.12, J_MAX: 7.37, P_MAX: 0.81
# n = 22G_MAX: 127.23, Q_MAX: 972.89, J_MAX: 7.67, P_MAX: 0.74
# n = 23G_MAX: 114.85, Q_MAX: 926.11, J_MAX: 8.01, P_MAX: 0.67
# n = 24G_MAX: 102.32, Q_MAX: 875.17, J_MAX: 8.43, P_MAX: 0.59
# n = 25G_MAX: 89.46, Q_MAX: 820.28, J_MAX: 8.94, P_MAX: 0.52
# n = 26G_MAX: 76.37, Q_MAX: 761.22, J_MAX: 9.57, P_MAX: 0.44
# n = 27G_MAX: 63.32, Q_MAX: 696.93, J_MAX: 10.39, P_MAX: 0.37
# n = 28G_MAX: 50.11, Q_MAX: 624.28, J_MAX: 11.52, P_MAX: 0.29
# n = 29G_MAX: 36.19, Q_MAX: 536.89, J_MAX: 13.26, P_MAX: 0.21
# n = 30G_MAX: 20.93, Q_MAX: 417.21, J_MAX: 16.76, P_MAX: 0.12
# n = 31G_MAX: 148.09, Q_MAX: 1149.07, J_MAX: 7.98, P_MAX: 0.86
# n = 32G_MAX: 134.99, Q_MAX: 1096.96, J_MAX: 8.30, P_MAX: 0.78
# n = 33G_MAX: 121.82, Q_MAX: 1042.33, J_MAX: 8.66, P_MAX: 0.71
# n = 34G_MAX: 108.46, Q_MAX: 983.54, J_MAX: 9.10, P_MAX: 0.63
# n = 35G_MAX: 94.76, Q_MAX: 919.95, J_MAX: 9.64, P_MAX: 0.55
# n = 36G_MAX: 80.81, Q_MAX: 851.44, J_MAX: 10.31, P_MAX: 0.47
# n = 37G_MAX: 66.89, Q_MAX: 777.11, J_MAX: 11.19, P_MAX: 0.39
# n = 38G_MAX: 52.77, Q_MAX: 693.53, J_MAX: 12.40, P_MAX: 0.31
# n = 39G_MAX: 37.86, Q_MAX: 593.04, J_MAX: 14.29, P_MAX: 0.22
# n = 40G_MAX: 21.28, Q_MAX: 454.30, J_MAX: 18.20, P_MAX: 0.12
# n = 41G_MAX: 156.92, Q_MAX: 1315.84, J_MAX: 8.66, P_MAX: 0.91
# n = 42G_MAX: 142.98, Q_MAX: 1251.66, J_MAX: 8.99, P_MAX: 0.83
# n = 43G_MAX: 129.00, Q_MAX: 1183.44, J_MAX: 9.38, P_MAX: 0.75
# n = 44G_MAX: 114.81, Q_MAX: 1111.70, J_MAX: 9.85, P_MAX: 0.67
# n = 45G_MAX: 100.24, Q_MAX: 1036.38, J_MAX: 10.42, P_MAX: 0.58
# n = 46G_MAX: 85.39, Q_MAX: 956.06, J_MAX: 11.13, P_MAX: 0.50
# n = 47G_MAX: 70.58, Q_MAX: 868.74, J_MAX: 12.06, P_MAX: 0.41
# n = 48G_MAX: 55.51, Q_MAX: 770.46, J_MAX: 13.35, P_MAX: 0.32
# n = 49G_MAX: 39.58, Q_MAX: 653.70, J_MAX: 15.39, P_MAX: 0.23
# n = 50G_MAX: 21.62, Q_MAX: 494.55, J_MAX: 19.73, P_MAX: 0.13
# n = 51G_MAX: 165.97, Q_MAX: 1533.87, J_MAX: 9.43, P_MAX: 0.96
# n = 52G_MAX: 151.24, Q_MAX: 1456.05, J_MAX: 9.78, P_MAX: 0.88
# n = 53G_MAX: 136.39, Q_MAX: 1372.81, J_MAX: 10.19, P_MAX: 0.79
# n = 54G_MAX: 121.32, Q_MAX: 1284.86, J_MAX: 10.67, P_MAX: 0.70
# n = 55G_MAX: 105.87, Q_MAX: 1192.19, J_MAX: 11.27, P_MAX: 0.61
# n = 56G_MAX: 90.11, Q_MAX: 1094.91, J_MAX: 12.02, P_MAX: 0.52
# n = 57G_MAX: 74.38, Q_MAX: 989.70, J_MAX: 13.00, P_MAX: 0.43
# n = 58G_MAX: 58.34, Q_MAX: 872.42, J_MAX: 14.38, P_MAX: 0.34
# n = 59G_MAX: 41.35, Q_MAX: 733.58, J_MAX: 16.57, P_MAX: 0.24
# n = 60G_MAX: 21.95, Q_MAX: 543.99, J_MAX: 21.38, P_MAX: 0.13
# n = 61G_MAX: 175.30, Q_MAX: 1770.23, J_MAX: 10.27, P_MAX: 1.02
# n = 62G_MAX: 159.70, Q_MAX: 1676.00, J_MAX: 10.64, P_MAX: 0.93
# n = 63G_MAX: 143.99, Q_MAX: 1577.16, J_MAX: 11.06, P_MAX: 0.84
# n = 64G_MAX: 128.04, Q_MAX: 1471.51, J_MAX: 11.58, P_MAX: 0.74
# n = 65G_MAX: 111.66, Q_MAX: 1360.35, J_MAX: 12.20, P_MAX: 0.65
# n = 66G_MAX: 94.96, Q_MAX: 1243.57, J_MAX: 12.99, P_MAX: 0.55
# n = 67G_MAX: 78.29, Q_MAX: 1118.82, J_MAX: 14.03, P_MAX: 0.45
# n = 68G_MAX: 61.24, Q_MAX: 980.65, J_MAX: 15.49, P_MAX: 0.36
# n = 69G_MAX: 43.17, Q_MAX: 817.65, J_MAX: 17.84, P_MAX: 0.25
# n = 70G_MAX: 22.27, Q_MAX: 594.73, J_MAX: 23.14, P_MAX: 0.13
# n = 71G_MAX: 184.92, Q_MAX: 2026.02, J_MAX: 11.21, P_MAX: 1.07
# n = 72G_MAX: 168.40, Q_MAX: 1911.89, J_MAX: 11.58, P_MAX: 0.98
# n = 73G_MAX: 151.81, Q_MAX: 1795.08, J_MAX: 12.03, P_MAX: 0.88
# n = 74G_MAX: 134.94, Q_MAX: 1671.82, J_MAX: 12.56, P_MAX: 0.78
# n = 75G_MAX: 117.63, Q_MAX: 1540.44, J_MAX: 13.22, P_MAX: 0.68
# n = 76G_MAX: 99.96, Q_MAX: 1402.05, J_MAX: 14.04, P_MAX: 0.58
# n = 77G_MAX: 82.30, Q_MAX: 1255.78, J_MAX: 15.14, P_MAX: 0.48
# n = 78G_MAX: 64.22, Q_MAX: 1094.86, J_MAX: 16.68, P_MAX: 0.37
# n = 79G_MAX: 45.04, Q_MAX: 905.91, J_MAX: 19.18, P_MAX: 0.26
# n = 80G_MAX: 22.57, Q_MAX: 646.69, J_MAX: 25.01, P_MAX: 0.13
# n = 81G_MAX: 194.79, Q_MAX: 2349.00, J_MAX: 12.24, P_MAX: 1.13
# n = 82G_MAX: 177.37, Q_MAX: 2210.66, J_MAX: 12.63, P_MAX: 1.03
# n = 83G_MAX: 159.83, Q_MAX: 2068.09, J_MAX: 13.09, P_MAX: 0.93
# n = 84G_MAX: 142.05, Q_MAX: 1916.78, J_MAX: 13.64, P_MAX: 0.82
# n = 85G_MAX: 123.75, Q_MAX: 1759.12, J_MAX: 14.33, P_MAX: 0.72
# n = 86G_MAX: 105.09, Q_MAX: 1595.36, J_MAX: 15.19, P_MAX: 0.61
# n = 87G_MAX: 86.44, Q_MAX: 1421.68, J_MAX: 16.34, P_MAX: 0.50
# n = 88G_MAX: 67.28, Q_MAX: 1230.94, J_MAX: 17.96, P_MAX: 0.39
# n = 89G_MAX: 46.95, Q_MAX: 1008.97, J_MAX: 20.62, P_MAX: 0.27
# n = 90G_MAX: 22.85, Q_MAX: 708.10, J_MAX: 27.01, P_MAX: 0.13
# n = 91G_MAX: 204.89, Q_MAX: 2715.83, J_MAX: 13.36, P_MAX: 1.19
# n = 92G_MAX: 186.58, Q_MAX: 2550.67, J_MAX: 13.76, P_MAX: 1.08
# n = 93G_MAX: 168.07, Q_MAX: 2379.95, J_MAX: 14.24, P_MAX: 0.98
# n = 94G_MAX: 149.31, Q_MAX: 2199.66, J_MAX: 14.81, P_MAX: 0.87
# n = 95G_MAX: 130.03, Q_MAX: 2010.67, J_MAX: 15.52, P_MAX: 0.76
# n = 96G_MAX: 110.36, Q_MAX: 1814.27, J_MAX: 16.42, P_MAX: 0.64
# n = 97G_MAX: 90.67, Q_MAX: 1608.62, J_MAX: 17.62, P_MAX: 0.53
# n = 98G_MAX: 70.43, Q_MAX: 1384.35, J_MAX: 19.33, P_MAX: 0.41
# n = 99G_MAX: 48.91, Q_MAX: 1124.26, J_MAX: 22.14, P_MAX: 0.28
# n = 100G_MAX: 23.13, Q_MAX: 771.85, J_MAX: 29.13, P_MAX: 0.13

# %%
from scipy import interpolate

# %%
f1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(acc_net_g_max_array), kind='cubic')
q1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(q_stag_total_max_array), kind='cubic')
h1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(heatload_max_array), kind='cubic')
s1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(dyn_pres_array), kind='cubic')

x_new = np.linspace(10, 13, 100)
y_new = np.linspace(-20, -7, 100)


g1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
h1_new =  np.zeros((len(x_new),len(y_new)))
s1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        g1_new[i,j] = f1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        h1_new[i,j] = h1(x_new[i],y_new[j])
        s1_new[i,j] = s1(x_new[i],y_new[j])

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()
fig.set_size_inches([8, 8])
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

GCS1 = plt.contour(Y, X, np.transpose(g1_new), levels=15, linewidths=2.0, colors='black')
plt.clabel(GCS1, inline=1, fontsize=14, colors='black',fmt='%3d',inline_spacing=1)
#GCS1.collections[0].set_label(r'g-load')

QCS1 = plt.contour(Y, X, np.transpose(q1_new),  levels=15, linewidths=2.0, colors='red')
plt.clabel(QCS1, inline=1, fontsize=14, colors='red',fmt='%3d',inline_spacing=1)
#QCS1.collections[0].set_label(r'$\dot{q}$'+', '+r'$W/cm^2$')

HCS1 = plt.contour(Y, X, np.transpose(h1_new), levels=15, linewidths=2.0, colors='magenta')
plt.clabel(HCS1, inline=1, fontsize=14, colors='magenta',fmt='%3d',inline_spacing=1)
#HCS1.collections[0].set_label(r'$Q$'+', '+r'$kJ/cm^2$')

plt.xlabel("Planet relative EFPA "+r'$\gamma_e$'+r', deg' ,fontsize=16)
plt.ylabel(r'Entry speed, km/s' ,fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')


ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')

ax.xaxis.set_tick_params(width=2, length=8)
ax.yaxis.set_tick_params(width=2, length=8)

ax.xaxis.set_tick_params(width=1, length=6, which='minor')
ax.yaxis.set_tick_params(width=1, length=6, which='minor')


ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

h1,l1 = GCS1.legend_elements()
h2,l1 = QCS1.legend_elements()
h3,l1 = HCS1.legend_elements()

plt.legend([h1[0], h2[0], h3[0]], ['g-load', r'$\dot{q}$'+', '+r'$W/cm^2$', r'$Q$'+', '+r'$kJ/cm^2$'], 
           fontsize=14, loc='lower left', framealpha=1.0)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.scatter(-8.23, 12.45, marker="D", s=30, color='xkcd:green', zorder=2)
plt.annotate("Stardust", xy=(-8.23, 12.45), xytext=(-10.23, 12.45), va="center", ha="center",
            arrowprops=dict(arrowstyle='->, head_width=0.2', facecolor='blue'), 
            fontsize=14, color='b', bbox=dict(boxstyle='round,pad=0.2', fc='w', ec='k', alpha=1.0))

plt.scatter(-8.00, 10.8, marker="D", s=30, color='xkcd:green', zorder=2)
plt.annotate("Genesis", xy=(-8.00, 10.8), xytext=(-10.00, 10.8), va="center", ha="center",
            arrowprops=dict(arrowstyle='->, head_width=0.2', facecolor='blue'), 
              fontsize=14, color='b', bbox=dict(boxstyle='round,pad=0.2', fc='w', ec='k', alpha=1.0))

plt.scatter(-8.20, 12.2, marker="D", s=30, color='xkcd:green', zorder=2)
plt.annotate("OSIRIS-REX", xy=(-8.20, 12.2), xytext=(-10.00, 12.2), va="center", ha="center",
            arrowprops=dict(arrowstyle='->, head_width=0.2', facecolor='blue'), 
              fontsize=14, color='b', bbox=dict(boxstyle='round,pad=0.2', fc='w', ec='k', alpha=1.0))
plt.savefig('../plots/earth-sample-return.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
speedRange = np.linspace(10, 13, 5)
gammaRange = np.linspace(-30, -7, 5)

acc_net_g_max_array       = np.zeros((len(speedRange),len(gammaRange)))
q_stag_total_max_array    = np.zeros((len(speedRange),len(gammaRange)))
heatload_max_array        = np.zeros((len(speedRange),len(gammaRange)))
dyn_pres_array            = np.zeros((len(speedRange),len(gammaRange)))
n = 0

for i, speed in enumerate(speedRange):
    for j, gamma in enumerate(gammaRange):
        vehicle=Vehicle('ADEPT', 50, 25.0, 0.0, np.pi*1.5**2.0*0.25, 0.0, 0.20, planet)
        vehicle.setInitialState(120,0.0,0.0,speed,0.0,gamma,0.0,0.0)
        vehicle.setSolverParams(1E-6)
        vehicle.propogateEntry (20*60, 0.1, 0.0)
        n+=1
        print("n = " + str(n) +"G_MAX: "+str("{:.2f}".format(max(vehicle.acc_net_g)))+", Q_MAX: "+str("{:.2f}".format(max(vehicle.q_stag_total)))+", J_MAX: "+str("{:.2f}".format(max(vehicle.heatload/1.0E3)))+", P_MAX: "+str("{:.2f}".format(max(vehicle.dyn_pres_atm))))

        acc_net_g_max_array[i,j]     = max(vehicle.acc_net_g)
        q_stag_total_max_array[i,j]  = max(vehicle.q_stag_total)
        heatload_max_array[i,j]      = max(vehicle.heatload/1.0E3)
        dyn_pres_array[i,j]         = max(vehicle.dyn_pres_atm)
# Out:
# n = 1G_MAX: 117.96, Q_MAX: 561.59, J_MAX: 4.29, P_MAX: 0.29
# n = 2G_MAX: 95.83, Q_MAX: 510.60, J_MAX: 4.73, P_MAX: 0.23
# n = 3G_MAX: 72.85, Q_MAX: 449.41, J_MAX: 5.37, P_MAX: 0.18
# n = 4G_MAX: 49.20, Q_MAX: 372.06, J_MAX: 6.48, P_MAX: 0.12
# n = 5G_MAX: 22.61, Q_MAX: 257.11, J_MAX: 9.30, P_MAX: 0.05
# n = 6G_MAX: 135.68, Q_MAX: 715.61, J_MAX: 5.02, P_MAX: 0.33
# n = 7G_MAX: 110.04, Q_MAX: 647.70, J_MAX: 5.53, P_MAX: 0.27
# n = 8G_MAX: 83.43, Q_MAX: 566.78, J_MAX: 6.28, P_MAX: 0.20
# n = 9G_MAX: 55.84, Q_MAX: 465.21, J_MAX: 7.58, P_MAX: 0.14
# n = 10G_MAX: 24.06, Q_MAX: 312.49, J_MAX: 11.10, P_MAX: 0.06
# n = 11G_MAX: 154.69, Q_MAX: 916.34, J_MAX: 5.89, P_MAX: 0.37
# n = 12G_MAX: 125.29, Q_MAX: 823.09, J_MAX: 6.46, P_MAX: 0.30
# n = 13G_MAX: 94.77, Q_MAX: 713.75, J_MAX: 7.32, P_MAX: 0.23
# n = 14G_MAX: 62.95, Q_MAX: 579.05, J_MAX: 8.83, P_MAX: 0.15
# n = 15G_MAX: 25.51, Q_MAX: 376.89, J_MAX: 13.13, P_MAX: 0.06
# n = 16G_MAX: 174.96, Q_MAX: 1192.90, J_MAX: 6.90, P_MAX: 0.42
# n = 17G_MAX: 141.56, Q_MAX: 1062.54, J_MAX: 7.55, P_MAX: 0.34
# n = 18G_MAX: 106.88, Q_MAX: 912.22, J_MAX: 8.52, P_MAX: 0.26
# n = 19G_MAX: 70.54, Q_MAX: 728.78, J_MAX: 10.24, P_MAX: 0.17
# n = 20G_MAX: 26.98, Q_MAX: 455.40, J_MAX: 15.41, P_MAX: 0.07
# n = 21G_MAX: 196.51, Q_MAX: 1548.96, J_MAX: 8.09, P_MAX: 0.48
# n = 22G_MAX: 158.86, Q_MAX: 1366.99, J_MAX: 8.81, P_MAX: 0.38
# n = 23G_MAX: 119.75, Q_MAX: 1158.95, J_MAX: 9.89, P_MAX: 0.29
# n = 24G_MAX: 78.61, Q_MAX: 910.68, J_MAX: 11.82, P_MAX: 0.19
# n = 25G_MAX: 28.48, Q_MAX: 546.27, J_MAX: 17.95, P_MAX: 0.07

# %%
f1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(acc_net_g_max_array), kind='cubic')
q1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(q_stag_total_max_array), kind='cubic')
h1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(heatload_max_array), kind='cubic')
s1 = interpolate.interp2d(speedRange, gammaRange, np.transpose(dyn_pres_array), kind='cubic')

x_new = np.linspace(10, 13, 100)
y_new = np.linspace(-20, -7, 100)


g1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
h1_new =  np.zeros((len(x_new),len(y_new)))
s1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        g1_new[i,j] = f1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        h1_new[i,j] = h1(x_new[i],y_new[j])
        s1_new[i,j] = s1(x_new[i],y_new[j])

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()
fig.set_size_inches([8.00,8.00])
plt.ion()
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

GCS1 = plt.contour(Y, X, np.transpose(g1_new), levels=15, linewidths=2.0, colors='black')
plt.clabel(GCS1, inline=1, fontsize=14, colors='black',fmt='%3d',inline_spacing=1)
#GCS1.collections[0].set_label(r'g-load')

QCS1 = plt.contour(Y, X, np.transpose(q1_new),  levels=15, linewidths=2.0, colors='red')
plt.clabel(QCS1, inline=1, fontsize=14, colors='red',fmt='%3d',inline_spacing=1)
#QCS1.collections[0].set_label(r'$\dot{q}$'+', '+r'$W/cm^2$')

HCS1 = plt.contour(Y, X, np.transpose(h1_new), levels=15, linewidths=2.0, colors='magenta')
plt.clabel(HCS1, inline=1, fontsize=14, colors='magenta',fmt='%3d',inline_spacing=1)
#HCS1.collections[0].set_label(r'$Q$'+', '+r'$kJ/cm^2$')

plt.xlabel("Planet relative EFPA "+r'$\gamma_e$'+r', deg' ,fontsize=16)
plt.ylabel(r'Entry speed, km/s' ,fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')


ax.xaxis.set_tick_params(direction='in', which='both')
ax.yaxis.set_tick_params(direction='in', which='both')

ax.xaxis.set_tick_params(width=2, length=8)
ax.yaxis.set_tick_params(width=2, length=8)

ax.xaxis.set_tick_params(width=1, length=6, which='minor')
ax.yaxis.set_tick_params(width=1, length=6, which='minor')


ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.0)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

h1,l1 = GCS1.legend_elements()
h2,l1 = QCS1.legend_elements()
h3,l1 = HCS1.legend_elements()

plt.legend([h1[0], h2[0], h3[0]], ['g-load', r'$\dot{q}$'+', '+r'$W/cm^2$', r'$Q$'+', '+r'$kJ/cm^2$'], 
           fontsize=14, loc='lower left', framealpha=1)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

plt.savefig('../plots/earth-low-bc.png', dpi=300, bbox_inches='tight')
plt.show()
